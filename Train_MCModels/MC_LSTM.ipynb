# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ### Device 세팅

# %%
device = 'mps' if torch.backends.mps.is_available() else 'cpu'

torch.manual_seed(1)
if device == 'mps':
    torch.mps.manual_seed(1)

print(device)
# Out:
# mps

# %% [markdown]
# ### 모델 및 학습 정의

# %%
DROP_OUT_R = 0.5
LEARNING_RATE = 0.001

EPOCHS = 500
BATCH_SIZE = 50
Seq_length = 5
#VALIDATION_RATE = 0.1

CHECK_INTERVAL = 10
# EARLY_STOP = 30

# %%
class LSTM_use_VIT(nn.Module):
    def __init__(self):
        super().__init__()

        self.LSTM_layer = nn.LSTM(input_size=30,
                                hidden_size = 55,
                                num_layers = 1,
                                batch_first=True)
        
        self.FC_layer = nn.Sequential(
            nn.LeakyReLU(),
            nn.Dropout(DROP_OUT_R),
            nn.Linear(55,1)
        )
    
    def forward(self, input_x):
        lstm_y,_ = self.LSTM_layer(input_x)
        lstm_y = lstm_y[:,-1,:]

        y = self.FC_layer(lstm_y)

        return y

MC_LSTM = LSTM_use_VIT().to(device)

# %%
# 파라미터 개수 확인
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(count_parameters(MC_LSTM)) #사용
# Out:
# 19196

# %%
loss_func = nn.MSELoss()
optimizer = optim.Adam(MC_LSTM.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ### 학습 과정 정의

# %%
train_losses = []

# %%
def train_model(train_loader, epochs, check_interval):
    
    for e in range(epochs):
        train_loss = 0
        
        MC_LSTM.train()
        for x_batch, y_batch in train_loader:

            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            
            pred_y = MC_LSTM(x_batch)
            loss = loss_func(pred_y, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()    
            
            train_loss += loss.item()

        train_loss = train_loss/len(train_loader)
        train_losses.append(train_loss)
        
        if (e % check_interval) == 0:
            print("epoch : ", e, "train loss: ",train_losses[-1])

# %% [markdown]
# ### Custom Dataset Type 정의

# %%
class BAT_DATASET(Dataset):
    def __init__(self, X, y):
        super().__init__()
        X = deepcopy(X)
        y = deepcopy(y)
        self.X = X
        self.y = y
    
    def __len__(self):
        return len(self.X)
    

    def __getitem__(self, index):
        rX = self.X[index]
        ry = self.y[index]

        return rX, ry

# %% [markdown]
# ### Multi channel LSTM 데이터 준비 (Seq_length = 5(i ~ i+5사이클로 i+6사이클 예측할 예정) , input_feature = 30(한 cycle당 30개 데이터 사용))

# %%
def prepareXY_forLSTM(X_ndArray, y_ndArray, Seq_length):
   X_ndArray = X_ndArray.reshape(-1,30)
   X_data = []
   for idx in range(0, X_ndArray.shape[0]):
      if (idx+1)-Seq_length < 0:
         tmp = np.zeros((Seq_length-(idx+1), 30))
         tmp = np.concatenate((tmp, X_ndArray[0:idx+1]), axis=0)
         X_data.append(tmp)
      else:
         X_data.append(X_ndArray[(idx+1)-Seq_length:idx+1])
      
   X_data = np.array(X_data)

   return X_data, y_ndArray

# %% [markdown]
# ### ----- ⚠️ 파라미터 불러오기 ------------------------

# %% [markdown]
# params = torch.load("../BEST_MODEL/MC_LSTM_params.pt")
# LSTM.load_state_dict(params)

# %% [markdown]
# ### ----- B0006/B0007/B00018 데이터 학습 ------

# %%
X_scaler = MinMaxScaler(feature_range=(0,1))
y_scaler = MinMaxScaler(feature_range=(0,1))

def all_data_train_wrapper():
    data_file_indices = ["B0006", "B0007", "B0018"]

    for d_idx in data_file_indices: 
        
        x_df = pd.read_csv(f"../Data/DataFrame/{d_idx}_charge_df.csv").loc[:,["cycle", "voltage_measured", "current_measured", "temperature_measured", "time"]]
        y_df = pd.read_csv(f"../Data/DataFrame/{d_idx}_capacity_df.csv").loc[:,["capacity"]]

        x_df_10points = pd.DataFrame(columns=x_df.columns)

        for cyc in x_df["cycle"].unique():
            tmp_cycle_x_df = x_df[x_df["cycle"] == cyc]
            interval = len(tmp_cycle_x_df.index)//10
            choosed_idx = []
            for idx in range(0,len(tmp_cycle_x_df), interval):
                if len(choosed_idx) == 10 :
                        break
                choosed_idx.append(idx)

            x_df_10points = pd.concat([x_df_10points, tmp_cycle_x_df.iloc[choosed_idx]], axis=0)

        
        display(x_df_10points)

        RAW_XDATA = deepcopy(x_df_10points)
        RAW_yDATA = deepcopy(y_df)

        if data_file_indices.index(d_idx) == 0 :
            X_scaled = X_scaler.fit_transform(RAW_XDATA[["voltage_measured", "current_measured", "temperature_measured"]].values.reshape(-1,3))
            y_scaled = y_scaler.fit_transform(RAW_yDATA["capacity"].unique().reshape(-1,1))
        else:
            X_scaled = X_scaler.transform(RAW_XDATA[["voltage_measured", "current_measured", "temperature_measured"]].values.reshape(-1,3))
            y_scaled = y_scaler.transform(RAW_yDATA["capacity"].unique().reshape(-1,1))

        X_data, y_data= prepareXY_forLSTM(X_scaled, y_scaled, Seq_length)
        X_data = torch.from_numpy(X_data).type(torch.float)
        y_data = torch.from_numpy(y_data).type(torch.float)

        train_dataset = BAT_DATASET(X_data, y_data)

        train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle=False)
        
        train_model(train_loader, EPOCHS, CHECK_INTERVAL)

# %%
all_data_train_wrapper()
# Out:
#        cycle  voltage_measured  current_measured  temperature_measured  \
# 0          2          3.320249          1.515595             31.861155
# 76         2          3.772765          1.513079             29.518580
# 152        2          3.869867          1.512962             28.012962
# 228        2          3.928052          1.515339             27.151827
# 304        2          3.968767          1.513685             26.699932
# ...      ...               ...               ...                   ...
# 375596   169          4.198806          0.349829             25.757573
# 375852   169          4.199172          0.246677             24.935181
# 376108   169          4.199734          0.176216             24.455348
# 376364   169          4.199159          0.129508             24.188771
# 376620   169          4.196670          0.090274             23.976710
#
#             time
# 0          5.500
# 76       234.078
# 152      511.156
# 228      875.062
# 304     1364.266
# ...          ...
# 375596  3460.406
# 375852  4206.797
# 376108  4952.406
# 376364  5697.531
# 376620  6443.437
#
# [1670 rows x 5 columns]
# epoch :  0 train loss:  0.21263679792173207
# epoch :  10 train loss:  0.07265604380518198
# epoch :  20 train loss:  0.03907168912701309
# epoch :  30 train loss:  0.01974240702111274
# epoch :  40 train loss:  0.016036778106354177
# epoch :  50 train loss:  0.01672579545993358
# epoch :  60 train loss:  0.014236844377592206
# epoch :  70 train loss:  0.016581146570388228
# epoch :  80 train loss:  0.014224035083316267
# epoch :  90 train loss:  0.015754271240439266
# epoch :  100 train loss:  0.012141081388108432
# epoch :  110 train loss:  0.012793657020665705
# epoch :  120 train loss:  0.011033717717509717
# epoch :  130 train loss:  0.008233132073655725
# epoch :  140 train loss:  0.012056525505613536
# epoch :  150 train loss:  0.009772902179975063
# epoch :  160 train loss:  0.007682436524191871
# epoch :  170 train loss:  0.009928273255354725
# epoch :  180 train loss:  0.008639175837743096
# epoch :  190 train loss:  0.006514867098303512
# epoch :  200 train loss:  0.007616353846970014
# epoch :  210 train loss:  0.006820879876613617
# epoch :  220 train loss:  0.007503064232878387
# epoch :  230 train loss:  0.009616445808205754
# epoch :  240 train loss:  0.009576440512319095
# epoch :  250 train loss:  0.014655724284239113
# epoch :  260 train loss:  0.007650606887182221
# epoch :  270 train loss:  0.006038282299414277
# epoch :  280 train loss:  0.00741377696976997
# epoch :  290 train loss:  0.008188504085410386
# epoch :  300 train loss:  0.00953000872686971
# epoch :  310 train loss:  0.00715088055585511
# epoch :  320 train loss:  0.005483166212798096
# epoch :  330 train loss:  0.007203641172964126
# epoch :  340 train loss:  0.00785594474291429
# epoch :  350 train loss:  0.008967636327724904
# epoch :  360 train loss:  0.004883647139649838
# epoch :  370 train loss:  0.00800073507707566
# epoch :  380 train loss:  0.008238645707024261
# epoch :  390 train loss:  0.007471221353625879
# epoch :  400 train loss:  0.005908506893320009
# epoch :  410 train loss:  0.006094344105804339
# epoch :  420 train loss:  0.0038432144501712173
# epoch :  430 train loss:  0.005348650651285425
# epoch :  440 train loss:  0.005566928331973031
# epoch :  450 train loss:  0.006274069339269772
# epoch :  460 train loss:  0.005749142117565498
# epoch :  470 train loss:  0.00514966354239732
# epoch :  480 train loss:  0.007120226830011234
# epoch :  490 train loss:  0.00484435647376813
#        cycle  voltage_measured  current_measured  temperature_measured  \
# 0          2          3.270404          1.491025             30.573112
# 76         2          3.785553          1.491617             28.583428
# 152        2          3.881019          1.490421             27.391036
# 228        2          3.937696          1.491074             26.781612
# 304        2          3.978918          1.490915             26.575697
# ...      ...               ...               ...                   ...
# 375596   169          4.211561          0.512472             26.321016
# 375852   169          4.212398          0.330517             25.159387
# 376108   169          4.213197          0.224771             24.448661
# 376364   169          4.211974          0.149447             24.056267
# 376620   169          4.210804          0.096991             23.820288
#
#             time
# 0          5.500
# 76       234.078
# 152      511.156
# 228      875.062
# 304     1364.266
# ...          ...
# 375596  3460.406
# 375852  4206.797
# 376108  4952.406
# 376364  5697.531
# 376620  6443.437
#
# [1670 rows x 5 columns]
# epoch :  0 train loss:  0.006301568500930443
# epoch :  10 train loss:  0.0037743761349702254
# epoch :  20 train loss:  0.003552791866241023
# epoch :  30 train loss:  0.004537976856227033
# epoch :  40 train loss:  0.0030232302960939705
# epoch :  50 train loss:  0.0032511236640857533
# epoch :  60 train loss:  0.002803853349178098
# epoch :  70 train loss:  0.0037250743771437556
# epoch :  80 train loss:  0.0024692211700312328
# epoch :  90 train loss:  0.0025238169910153374
# epoch :  100 train loss:  0.0024831426489981823
# epoch :  110 train loss:  0.0026299382298020646
# epoch :  120 train loss:  0.002824129958753474
# epoch :  130 train loss:  0.0026467398638487794
# epoch :  140 train loss:  0.0019719108458957635
# epoch :  150 train loss:  0.002975703027914278
# epoch :  160 train loss:  0.0023260199741343968
# epoch :  170 train loss:  0.0018986293507623486
# epoch :  180 train loss:  0.0024605861690361053
# epoch :  190 train loss:  0.00235942274593981
# epoch :  200 train loss:  0.0021986808751535136
# epoch :  210 train loss:  0.001823784041334875
# epoch :  220 train loss:  0.002523272283724509
# epoch :  230 train loss:  0.0019654445932246745
# epoch :  240 train loss:  0.0020632850646506995
# epoch :  250 train loss:  0.002255298553791363
# epoch :  260 train loss:  0.0017988819236052223
# epoch :  270 train loss:  0.0021157378650968894
# epoch :  280 train loss:  0.0020979741675546393
# epoch :  290 train loss:  0.0019511657883413136
# epoch :  300 train loss:  0.0016747380650485866
# epoch :  310 train loss:  0.001575905982463155
# epoch :  320 train loss:  0.0016706115857232362
# epoch :  330 train loss:  0.0018008027036557905
# epoch :  340 train loss:  0.0015593786010867916
# epoch :  350 train loss:  0.0022709941695211455
# epoch :  360 train loss:  0.002337453654035926
# epoch :  370 train loss:  0.0015688440762460232
# epoch :  380 train loss:  0.001995707891182974
# epoch :  390 train loss:  0.001596443929884117
# epoch :  400 train loss:  0.0013317923403519671
# epoch :  410 train loss:  0.0011242589971516281
# epoch :  420 train loss:  0.0015554655255982652
# epoch :  430 train loss:  0.0012212984220241196
# epoch :  440 train loss:  0.0016183143525267951
# epoch :  450 train loss:  0.0014458776568062603
# epoch :  460 train loss:  0.0013820248568663374
# epoch :  470 train loss:  0.00180195044958964
# epoch :  480 train loss:  0.001525317071354948
# epoch :  490 train loss:  0.001924810276250355
#        cycle  voltage_measured  current_measured  temperature_measured  \
# 0          2          3.479525          1.515638             24.286875
# 257        2          3.938450          1.516332             24.243205
# 514        2          3.997673          1.515629             25.168382
# 771        2          4.049742          1.515579             26.206501
# 1028       2          4.124331          1.517625             27.305446
# ...      ...               ...               ...                   ...
# 190602   134          4.198443          0.425873             25.797876
# 190702   134          4.198810          0.274652             24.716367
# 190802   134          4.200036          0.192107             24.088869
# 190902   134          4.199606          0.136557             23.701478
# 191002   134          4.199994          0.098644             23.462057
#
#             time
# 0          5.219
# 257      653.547
# 514     1303.219
# 771     1952.907
# 1028    2602.360
# ...          ...
# 190602  3527.000
# 190702  4252.766
# 190802  4977.859
# 190902  5706.000
# 191002  6431.531
#
# [1310 rows x 5 columns]
# epoch :  0 train loss:  0.0028992800507694483
# epoch :  10 train loss:  0.002126614951218168
# epoch :  20 train loss:  0.0019131960580125451
# epoch :  30 train loss:  0.001973535632714629
# epoch :  40 train loss:  0.0016424880595877767
# epoch :  50 train loss:  0.0021347084742349884
# epoch :  60 train loss:  0.0020045150304213166
# epoch :  70 train loss:  0.0019363522878848016
# epoch :  80 train loss:  0.0015605941880494356
# epoch :  90 train loss:  0.002129026882660886
# epoch :  100 train loss:  0.001271463988814503
# epoch :  110 train loss:  0.0016388562313901882
# epoch :  120 train loss:  0.0017273604947452743
# epoch :  130 train loss:  0.0020594483939930797
# epoch :  140 train loss:  0.001676045455193768
# epoch :  150 train loss:  0.0013585148844867945
# epoch :  160 train loss:  0.0014202869109188516
# epoch :  170 train loss:  0.0011612015077844262
# epoch :  180 train loss:  0.0014087966216417651
# epoch :  190 train loss:  0.001563058642204851
# epoch :  200 train loss:  0.0015431225183419883
# epoch :  210 train loss:  0.001375009228164951
# epoch :  220 train loss:  0.0018168293948595722
# epoch :  230 train loss:  0.0016097632663634915
# epoch :  240 train loss:  0.0014333863897869985
# epoch :  250 train loss:  0.0014647791006912787
# epoch :  260 train loss:  0.0016971005825325847
# epoch :  270 train loss:  0.0013656443334184587
# epoch :  280 train loss:  0.001712970610242337
# epoch :  290 train loss:  0.0014736544302043815
# epoch :  300 train loss:  0.00139789649983868
# epoch :  310 train loss:  0.0018445166836803157
# epoch :  320 train loss:  0.0010510000283829868
# epoch :  330 train loss:  0.0014002260674412053
# epoch :  340 train loss:  0.001310101031170537
# epoch :  350 train loss:  0.0013737388653680682
# epoch :  360 train loss:  0.0013237615445783983
# epoch :  370 train loss:  0.0013141821837052703
# epoch :  380 train loss:  0.0011601738127258916
# epoch :  390 train loss:  0.0016354356581966083
# epoch :  400 train loss:  0.001467942085582763
# epoch :  410 train loss:  0.0012898362474516034
# epoch :  420 train loss:  0.0009149599257701387
# epoch :  430 train loss:  0.0014167033853785445
# epoch :  440 train loss:  0.0011706686151834826
# epoch :  450 train loss:  0.0012188412559529145
# epoch :  460 train loss:  0.0013291157665662467
# epoch :  470 train loss:  0.0012755874389161666
# epoch :  480 train loss:  0.0016109527205117047
# epoch :  490 train loss:  0.0011351818781501304

# %% [markdown]
# ### ----- ⚠️ 새로운 파라미터 저장 ------------------------

# %% [markdown]
# MC_LSTM_params = MC_LSTM.state_dict()
# torch.save(MC_LSTM_params, "../BEST_MODEL/MC_LSTM_params.pt")

# %% [markdown]
# ### B0005 예측

# %%
x_df = pd.read_csv(f"../Data/DataFrame/B0005_charge_df.csv").loc[:,["cycle", "voltage_measured", "current_measured", "temperature_measured", "time"]]
y_df = pd.read_csv(f"../Data/DataFrame/B0005_capacity_df.csv").loc[:,["capacity"]]

x_df_10points = pd.DataFrame(columns=x_df.columns)
for cyc in x_df["cycle"].unique():
    tmp_cycle_x_df = x_df[x_df["cycle"] == cyc]
    interval = len(tmp_cycle_x_df.index)//10
    choosed_idx = []
    for idx in range(0,len(tmp_cycle_x_df), interval):
        if len(choosed_idx) == 10 :
            break
        choosed_idx.append(idx)

    x_df_10points = pd.concat([x_df_10points, tmp_cycle_x_df.iloc[choosed_idx]], axis=0)    
display(x_df_10points)

RAW_XDATA = deepcopy(x_df_10points)
RAW_yDATA = deepcopy(y_df)

X_scaled = X_scaler.transform(RAW_XDATA[["voltage_measured", "current_measured", "temperature_measured"]].values.reshape(-1,3))
y_scaled = y_scaler.transform(RAW_yDATA["capacity"].unique().reshape(-1,1))
        
X_data, y_data= prepareXY_forLSTM(X_scaled, y_scaled,Seq_length)
X_data = torch.from_numpy(X_data).type(torch.float)
y_data = torch.from_numpy(y_data).type(torch.float)

test_dataset = BAT_DATASET(X_data, y_data)

test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle=False)

predicts = []

MC_LSTM.eval()
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
            
        pred_y = MC_LSTM(x_batch)

        predicts.append(pred_y.to('cpu'))

predicts_concat = torch.cat(predicts, 0)
predicts_df = pd.DataFrame(y_scaler.inverse_transform(np.array(predicts_concat)))
# Out:
#        cycle  voltage_measured  current_measured  temperature_measured  \
# 0          2          3.434644          1.508670             29.334717
# 76         2          3.814079          1.510073             27.739727
# 152        2          3.881686          1.509227             26.890304
# 228        2          3.937241          1.508747             26.481944
# 304        2          3.979605          1.506559             26.476934
# ...      ...               ...               ...                   ...
# 375596   169          4.205285          0.409958             26.151950
# 375852   169          4.205106          0.261199             25.147212
# 376108   169          4.204985          0.184375             24.550544
# 376364   169          4.206357          0.135819             24.199547
# 376620   169          4.205151          0.093461             24.008512
#
#             time
# 0          5.500
# 76       234.078
# 152      511.156
# 228      875.062
# 304     1364.266
# ...          ...
# 375596  3460.406
# 375852  4206.797
# 376108  4952.406
# 376364  5697.531
# 376620  6443.437
#
# [1670 rows x 5 columns]

# %%
predicts_df
# Out:
#             0
# 0    1.876961
# 1    1.890841
# 2    1.897712
# 3    1.901038
# 4    1.905312
# ..        ...
# 162  1.354440
# 163  1.353043
# 164  1.350276
# 165  1.348858
# 166  1.361471
#
# [167 rows x 1 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 6]
plt.xlim([0, 160])

plt.plot(predicts_df.index, predicts_df.iloc[:,0], label='predict')
plt.plot(range(len(y_df.index)), y_df.iloc[:,0], label='real')
plt.plot(range(len(y_df.index)), [1.4 for i in range(len(y_df.index))], color='black')

plt.legend()
plt.show()

# %% [markdown]
# predicts_df.to_csv("../PREDICT/MC_LSTM.csv", index = False)
