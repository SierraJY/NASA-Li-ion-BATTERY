# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ### Device 세팅

# %%
device = 'mps' if torch.backends.mps.is_available() else 'cpu'

torch.manual_seed(1)
if device == 'mps':
    torch.mps.manual_seed(1)

print(device)
# Out:
# mps

# %% [markdown]
# ### 모델 및 학습 정의

# %%
DROP_OUT_R = 0.5
LEARNING_RATE = 0.001

EPOCHS = 500
BATCH_SIZE = 50
#VALIDATION_RATE = 0.1

CHECK_INTERVAL = 10
# EARLY_STOP = 30

# %%
class CNN_use_VIT(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv_layer = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=10, kernel_size=(1,2)),
            nn.Dropout(DROP_OUT_R),
            nn.LeakyReLU(),
            nn.Conv2d(in_channels=10, out_channels=5, kernel_size=(1,2)),
            nn.Dropout(DROP_OUT_R),
            nn.LeakyReLU()
        )

        self.linear_layer = nn.Sequential(
            nn.Linear(5*1*28,1),
            nn.LeakyReLU()
        )

    def forward(self, input_X):
        X1 = self.conv_layer(input_X)
        X1_flatten = X1.view(X1.shape[0], -1)
        y = self.linear_layer(X1_flatten)
        return y

MC_CNN_10K_5K = CNN_use_VIT().to(device)

# %%
# 파라미터 개수 확인
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(count_parameters(MC_CNN_10K_5K)) #사용
# Out:
# 276

# %%
loss_func = nn.MSELoss()
optimizer = optim.Adam(MC_CNN_10K_5K.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ### 학습 과정 정의

# %%
train_losses = []

# %%
def train_model(train_loader, epochs, check_interval):
    
    for e in range(epochs):
        train_loss = 0
        
        MC_CNN_10K_5K.train()
        for x_batch, y_batch in train_loader:

            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            
            pred_y = MC_CNN_10K_5K(x_batch)
            loss = loss_func(pred_y, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()    
            
            train_loss += loss.item()

        train_loss = train_loss/len(train_loader)
        train_losses.append(train_loss)
        
        if (e % check_interval) == 0:
            print("epoch : ", e, "train loss: ",train_losses[-1])

# %% [markdown]
# ### Custom Dataset Type 정의

# %%
class BAT_DATASET(Dataset):
    def __init__(self, X, y):
        super().__init__()
        X = deepcopy(X)
        y = deepcopy(y)
        self.X = X
        self.y = y
    
    def __len__(self):
        return len(self.X)
    

    def __getitem__(self, index):
        rX = self.X[index]
        ry = self.y[index]

        return rX, ry

# %% [markdown]
# ### 데이터 묶기 (10개씩)

# %%
# 10개의 Voltage_measured로 다음 번째의 Capacity를 예측
# Voltage_measure 10개씩 묶어 준비 n개 준비
# Capacity도 n개 준비

def prepareXY(X_ndArray, y_ndArray):
   X_data = list()

   for idx in range(0,len(X_ndArray), 10):
      X_data.append(X_ndArray[idx: idx+10].reshape(-1,30)) # Transpose필요, FNN에 10 seq_length를 넣음 (즉, 10 feature처럼)

   X_data = np.array(X_data)

   return X_data, y_ndArray

# %% [markdown]
# ### ----- ⚠️ 파라미터 불러오기 ------------------------

# %% [markdown]
# params = torch.load("../BEST_MODEL/MC_CNN_10K_5K_params.pt")
# MC_CNN_10K_5K.load_state_dict(params)

# %% [markdown]
# ### ----- B0006/B0007/B00018 데이터 학습 ------

# %%
def all_data_train_wrapper():
    data_file_indices = ["B0006", "B0007", "B0018"]

    for d_idx in data_file_indices: 
        
        x_df = pd.read_csv(f"../DATA/DataFrame/{d_idx}_charge_df.csv").loc[:,["cycle", "voltage_measured", "current_measured", "temperature_measured", "time"]]
        y_df = pd.read_csv(f"../DATA/DataFrame/{d_idx}_capacity_df.csv").loc[:,["capacity"]]

        x_df_10points = pd.DataFrame(columns=x_df.columns)

        for cyc in x_df["cycle"].unique():
            tmp_cycle_x_df = x_df[x_df["cycle"] == cyc]
            interval = len(tmp_cycle_x_df.index)//10
            choosed_idx = []
            for idx in range(0,len(tmp_cycle_x_df), interval):
                if len(choosed_idx) == 10 :
                        break
                choosed_idx.append(idx)

            x_df_10points = pd.concat([x_df_10points, tmp_cycle_x_df.iloc[choosed_idx]], axis=0)

        
        display(x_df_10points)

        X_scaler = MinMaxScaler(feature_range=(0,1))
        y_scaler = MinMaxScaler(feature_range=(0,1))

        RAW_XDATA = deepcopy(x_df_10points)
        RAW_yDATA = deepcopy(y_df)

        X_scaled = X_scaler.fit_transform(RAW_XDATA[["voltage_measured", "current_measured", "temperature_measured"]].values.reshape(-1,3))
        y_scaled = y_scaler.fit_transform(RAW_yDATA["capacity"].unique().reshape(-1,1))

        X_data, y_data= prepareXY(X_scaled, y_scaled)
        X_data = torch.from_numpy(X_data).type(torch.float).reshape(X_data.shape[0],1,1,30)
        y_data = torch.from_numpy(y_data).type(torch.float)

        train_dataset = BAT_DATASET(X_data, y_data)

        train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle=False)

        train_model(train_loader, EPOCHS, CHECK_INTERVAL)

# %%
all_data_train_wrapper()
# Out:
#        cycle  voltage_measured  current_measured  temperature_measured  \
# 0          2          3.320249          1.515595             31.861155
# 76         2          3.772765          1.513079             29.518580
# 152        2          3.869867          1.512962             28.012962
# 228        2          3.928052          1.515339             27.151827
# 304        2          3.968767          1.513685             26.699932
# ...      ...               ...               ...                   ...
# 375596   169          4.198806          0.349829             25.757573
# 375852   169          4.199172          0.246677             24.935181
# 376108   169          4.199734          0.176216             24.455348
# 376364   169          4.199159          0.129508             24.188771
# 376620   169          4.196670          0.090274             23.976710
#
#             time
# 0          5.500
# 76       234.078
# 152      511.156
# 228      875.062
# 304     1364.266
# ...          ...
# 375596  3460.406
# 375852  4206.797
# 376108  4952.406
# 376364  5697.531
# 376620  6443.437
#
# [1670 rows x 5 columns]
# epoch :  0 train loss:  0.1971597101073712
# epoch :  10 train loss:  0.10874538030475378
# epoch :  20 train loss:  0.09940749313682318
# epoch :  30 train loss:  0.08853343548253179
# epoch :  40 train loss:  0.06768616940826178
# epoch :  50 train loss:  0.06121279392391443
# epoch :  60 train loss:  0.050080886110663414
# epoch :  70 train loss:  0.04642056114971638
# epoch :  80 train loss:  0.04826311022043228
# epoch :  90 train loss:  0.04037129878997803
# epoch :  100 train loss:  0.03835373930633068
# epoch :  110 train loss:  0.03130541881546378
# epoch :  120 train loss:  0.034563117660582066
# epoch :  130 train loss:  0.02788199530914426
# epoch :  140 train loss:  0.027779317926615477
# epoch :  150 train loss:  0.023414601106196642
# epoch :  160 train loss:  0.0267691807821393
# epoch :  170 train loss:  0.02728605642914772
# epoch :  180 train loss:  0.020601746160537004
# epoch :  190 train loss:  0.024141678120940924
# epoch :  200 train loss:  0.022504005348309875
# epoch :  210 train loss:  0.02231915178708732
# epoch :  220 train loss:  0.023801752598956227
# epoch :  230 train loss:  0.019303594017401338
# epoch :  240 train loss:  0.02005811035633087
# epoch :  250 train loss:  0.017499959329143167
# epoch :  260 train loss:  0.016908055520616472
# epoch :  270 train loss:  0.0206488068215549
# epoch :  280 train loss:  0.02048706798814237
# epoch :  290 train loss:  0.016849749023094773
# epoch :  300 train loss:  0.01777316047810018
# epoch :  310 train loss:  0.01792015158571303
# epoch :  320 train loss:  0.019847710616886616
#        cycle  voltage_measured  current_measured  temperature_measured  \
# 0          2          3.479525          1.515638             24.286875
# 257        2          3.938450          1.516332             24.243205
# 514        2          3.997673          1.515629             25.168382
# 771        2          4.049742          1.515579             26.206501
# 1028       2          4.124331          1.517625             27.305446
# ...      ...               ...               ...                   ...
# 190602   134          4.198443          0.425873             25.797876
# 190702   134          4.198810          0.274652             24.716367
# 190802   134          4.200036          0.192107             24.088869
# 190902   134          4.199606          0.136557             23.701478
# 191002   134          4.199994          0.098644             23.462057
#
#             time
# 0          5.219
# 257      653.547
# 514     1303.219
# 771     1952.907
# 1028    2602.360
# ...          ...
# 190602  3527.000
# 190702  4252.766
# 190802  4977.859
# 190902  5706.000
# 191002  6431.531
#
# [1310 rows x 5 columns]
# epoch :  0 train loss:  0.025427396098772686
# epoch :  10 train loss:  0.026489015047748882
# epoch :  20 train loss:  0.02080199991663297
# epoch :  30 train loss:  0.02140536221365134
# epoch :  40 train loss:  0.0232123713940382
# epoch :  50 train loss:  0.019434647945066292
# epoch :  60 train loss:  0.01682714217652877
# epoch :  70 train loss:  0.020173406849304836
# epoch :  80 train loss:  0.01631298754364252
# epoch :  90 train loss:  0.01831871612618367
# epoch :  100 train loss:  0.015206233908732733
# epoch :  110 train loss:  0.013999143615365028
# epoch :  120 train loss:  0.01579828808705012
# epoch :  130 train loss:  0.017613792481521767
# epoch :  140 train loss:  0.01732595668484767
# epoch :  150 train loss:  0.018045200345416863
# epoch :  160 train loss:  0.01673596662779649
# epoch :  170 train loss:  0.018459693528711796
# epoch :  180 train loss:  0.01593512762337923
# epoch :  190 train loss:  0.015860881345967453
# epoch :  200 train loss:  0.017100607355435688
# epoch :  210 train loss:  0.011617658970256647
# epoch :  220 train loss:  0.017023771690825622
# epoch :  230 train loss:  0.014529761237402758
# epoch :  240 train loss:  0.015311990243693193
# epoch :  250 train loss:  0.01569185219705105
# epoch :  260 train loss:  0.015975470033784706
# epoch :  270 train loss:  0.019832238865395386
# epoch :  280 train loss:  0.012492953799664974
# epoch :  290 train loss:  0.016280125826597214
# epoch :  300 train loss:  0.016832342992226284
# epoch :  310 train loss:  0.01308680015305678
# epoch :  320 train loss:  0.016773690780003864
# epoch :  330 train loss:  0.018691271543502808
# epoch :  340 train loss:  0.013514177408069372
# epoch :  350 train loss:  0.014498862127463022
# epoch :  360 train loss:  0.01624291545401017
# epoch :  370 train loss:  0.013417904265224934
# epoch :  380 train loss:  0.016973139407734077
# epoch :  390 train loss:  0.01889731114109357
# epoch :  400 train loss:  0.01146252794812123
# epoch :  410 train loss:  0.014665897625188032
# epoch :  420 train loss:  0.015066389925777912
# epoch :  430 train loss:  0.018137278656164806
# epoch :  440 train loss:  0.013134523605306944
# epoch :  450 train loss:  0.016323671055336792
# epoch :  460 train loss:  0.014874480664730072
# epoch :  470 train loss:  0.011459025864799818
# epoch :  480 train loss:  0.014611339507003626
# epoch :  490 train loss:  0.015130549669265747

# %% [markdown]
# ### ----- ⚠️ 새로운 파라미터 저장 ------------------------

# %% [markdown]
# MC_CNN_10K_5K_params = MC_CNN_10K_5K.state_dict()
# torch.save(MC_CNN_10K_5K_params, "../BEST_MODEL/CNN_10K_5K_params.pt")

# %% [markdown]
# ### B0005 예측

# %%
x_df = pd.read_csv(f"../DATA/DataFrame/B0005_charge_df.csv").loc[:,["cycle", "voltage_measured", "current_measured", "temperature_measured", "time"]]
y_df = pd.read_csv(f"../DATA/DataFrame/B0005_capacity_df.csv").loc[:,["capacity"]]

x_df_10points = pd.DataFrame(columns=x_df.columns)
for cyc in x_df["cycle"].unique():
    tmp_cycle_x_df = x_df[x_df["cycle"] == cyc]
    interval = len(tmp_cycle_x_df.index)//10
    choosed_idx = []
    for idx in range(0,len(tmp_cycle_x_df), interval):
        if len(choosed_idx) == 10 :
            break
        choosed_idx.append(idx)

    x_df_10points = pd.concat([x_df_10points, tmp_cycle_x_df.iloc[choosed_idx]], axis=0)    
display(x_df_10points)

X_scaler = MinMaxScaler(feature_range=(0,1))
y_scaler = MinMaxScaler(feature_range=(0,1))

RAW_XDATA = deepcopy(x_df_10points)
RAW_yDATA = deepcopy(y_df)

X_scaled = X_scaler.fit_transform(RAW_XDATA[["voltage_measured", "current_measured", "temperature_measured"]].values.reshape(-1,3))
y_scaled = y_scaler.fit_transform(RAW_yDATA["capacity"].unique().reshape(-1,1))
        
X_data, y_data= prepareXY(X_scaled, y_scaled)
X_data = torch.from_numpy(X_data).type(torch.float).reshape(X_data.shape[0],1,1,30)
y_data = torch.from_numpy(y_data).type(torch.float)

test_dataset = BAT_DATASET(X_data, y_data)

test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle=False)

predicts = []

MC_CNN_10K_5K.eval()
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
            
        pred_y = MC_CNN_10K_5K(x_batch)

        predicts.append(pred_y.to('cpu'))

predicts_concat = torch.cat(predicts, 0)
predicts_df = pd.DataFrame(y_scaler.inverse_transform(np.array(predicts_concat)))
# Out:
#        cycle  voltage_measured  current_measured  temperature_measured  \
# 0          2          3.434644          1.508670             29.334717
# 76         2          3.814079          1.510073             27.739727
# 152        2          3.881686          1.509227             26.890304
# 228        2          3.937241          1.508747             26.481944
# 304        2          3.979605          1.506559             26.476934
# ...      ...               ...               ...                   ...
# 375596   169          4.205285          0.409958             26.151950
# 375852   169          4.205106          0.261199             25.147212
# 376108   169          4.204985          0.184375             24.550544
# 376364   169          4.206357          0.135819             24.199547
# 376620   169          4.205151          0.093461             24.008512
#
#             time
# 0          5.500
# 76       234.078
# 152      511.156
# 228      875.062
# 304     1364.266
# ...          ...
# 375596  3460.406
# 375852  4206.797
# 376108  4952.406
# 376364  5697.531
# 376620  6443.437
#
# [1670 rows x 5 columns]

# %%
predicts_df
# Out:
#             0
# 0    2.016025
# 1    2.004979
# 2    2.003081
# 3    2.005460
# 4    2.012806
# ..        ...
# 162  1.286290
# 163  1.286273
# 164  1.286021
# 165  1.286013
# 166  1.286574
#
# [167 rows x 1 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 6]
plt.xlim([0, 160])

plt.plot(predicts_df.index, predicts_df.iloc[:,0], label='predict')
plt.plot(range(len(y_df.index)), y_df.iloc[:,0], label='real')
plt.plot(range(len(y_df.index)), [1.4 for i in range(len(y_df.index))], color='black')

plt.legend()
plt.show()

# %% [markdown]
# predicts_df.to_csv("../PREDICT/MC_CNN_10K_5K.csv", index = False)
